# %% [markdown]
# # **Connecting to drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **Importing libraries**

# %%
import pandas as pd
import numpy as np
import os
from geopy.geocoders import Nominatim # Longutude and Latitude
# !pip install pycountry_convert
import pycountry_convert as pc
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # **Data Aggregation**

# %% [markdown]
# ### 1. Automated importing and basic cleaning of the 25 dataframes from the website "Our World in Data", preparing them for merging
# source: https://ourworldindata.org/

# %%
def Our_World_in_Data_CLEANING(csv_address, file_name):
  df = pd.read_csv(csv_address)
  df.rename(columns={'Entity':'Country','Day':'Date'},inplace=True)
  df.drop('Code', axis=1, inplace=True)

  return df

dir = '/content/drive/MyDrive/COVID 19 Data/Our_World_in_Data'

flag = 0
merged_df = pd.DataFrame()
DFcounter = 0
for file in os.listdir(dir):
  
  if file.endswith(".csv"):
    file_name = file
    csv_address = '/content/drive/MyDrive/COVID 19 Data/Our_World_in_Data/'+file_name

    df = Our_World_in_Data_CLEANING(csv_address, file_name)
    #if min(df['Date']) >= '2020-02-17':
    if min(df['Date']) > '2020-02-17':
      continue
    DFcounter+=1
    print(file_name,'countries:', len(df['Country'].unique()))
    print(file_name,'min date',min(df['Date']))
    print(file_name,'max date',max(df['Date']))
    print(' ')
    if flag == 0:
      merged_df =df
      flag = 1
    else:
      merged_df = pd.merge(df, merged_df, on=['Country','Date'])
print(DFcounter)

merged_df['Date'] = pd.to_datetime(merged_df['Date'])
print('[merged_df]')
print('Countries:', len(merged_df['Country'].unique()))
print('Min date',min(merged_df['Date']))
print('Max date',max(merged_df['Date']))
print('Shape',merged_df.shape)
# Out:
# covid-vaccination-policy.csv countries: 187
# covid-vaccination-policy.csv min date 2020-01-01
# covid-vaccination-policy.csv max date 2022-09-15
#
# covid-vaccine-age.csv countries: 186
# covid-vaccine-age.csv min date 2020-01-01
# covid-vaccine-age.csv max date 2022-09-15
#
# face-covering-policies-covid.csv countries: 187
# face-covering-policies-covid.csv min date 2020-01-01
# face-covering-policies-covid.csv max date 2022-09-15
#
# public-campaigns-covid.csv countries: 186
# public-campaigns-covid.csv min date 2020-01-01
# public-campaigns-covid.csv max date 2022-09-15
#
# covid-containment-and-health-index.csv countries: 181
# covid-containment-and-health-index.csv min date 2020-01-22
# covid-containment-and-health-index.csv max date 2022-09-13
#
# school-closures-covid.csv countries: 186
# school-closures-covid.csv min date 2020-01-21
# school-closures-covid.csv max date 2022-09-15
#
# workplace-closures-covid.csv countries: 186
# workplace-closures-covid.csv min date 2020-01-01
# workplace-closures-covid.csv max date 2022-09-15
#
# public-events-covid.csv countries: 186
# public-events-covid.csv min date 2020-01-01
# public-events-covid.csv max date 2022-09-15
#
# public-gathering-rules-covid.csv countries: 186
# public-gathering-rules-covid.csv min date 2020-01-01
# public-gathering-rules-covid.csv max date 2022-09-15
#
# stay-at-home-covid.csv countries: 186
# stay-at-home-covid.csv min date 2020-01-01
# stay-at-home-covid.csv max date 2022-09-15
#
# public-transport-covid.csv countries: 186
# public-transport-covid.csv min date 2020-01-01
# public-transport-covid.csv max date 2022-09-15
#
# internal-movement-covid.csv countries: 186
# internal-movement-covid.csv min date 2020-01-01
# internal-movement-covid.csv max date 2022-09-15
#
# international-travel-covid.csv countries: 186
# international-travel-covid.csv min date 2020-01-01
# international-travel-covid.csv max date 2022-09-15
#
# covid-19-testing-policy.csv countries: 186
# covid-19-testing-policy.csv min date 2020-01-01
# covid-19-testing-policy.csv max date 2022-09-15
#
# income-support-covid.csv countries: 186
# income-support-covid.csv min date 2020-01-01
# income-support-covid.csv max date 2022-09-15
#
# debt-relief-covid.csv countries: 186
# debt-relief-covid.csv min date 2020-01-01
# debt-relief-covid.csv max date 2022-09-15
#
# changes-visitors-covid.csv countries: 132
# changes-visitors-covid.csv min date 2020-02-17
# changes-visitors-covid.csv max date 2022-09-11
#
# 17
# [merged_df]
# Countries: 127
# Min date 2020-02-17 00:00:00
# Max date 2022-09-11 00:00:00
# Shape (116643, 24)

# %% [markdown]
# ### 2. Retrieving and cleaning of 3 dataframes
#
#
# *   Renaming the columns
# *   Converting 'Date' to date-time
# *   Prepared them for merging
#
# Source: https://covid19.who.int/data

# %%
CumulativeDF = pd.read_csv('/content/drive/MyDrive/COVID 19 Data/WHO/WHO-COVID-19-global-data.csv')
CumulativeDF.rename(columns={'Date_reported':'Date','Country_code':'country code'},inplace=True)
CumulativeDF['Date'] = pd.to_datetime(CumulativeDF['Date'])

LatestDF = pd.read_csv('/content/drive/MyDrive/COVID 19 Data/WHO/WHO-COVID-19-global-table-data.csv')
LatestDF.reset_index(inplace=True)
LatestDF = LatestDF.rename(columns={'index':'Country'})
LatestDF.drop('Deaths - newly reported in last 24 hours',axis=1,inplace=True)
LatestDF.dropna(inplace=True)

VaccineDF = pd.read_csv('/content/drive/MyDrive/COVID 19 Data/WHO/vaccination-data.csv')
VaccineDF = VaccineDF.rename(columns={'COUNTRY':'Country'})
VaccineDF.dropna(inplace=True)

CumulativeDF = CumulativeDF[CumulativeDF['Country'].isin(list(VaccineDF['Country']))]
LatestDF = LatestDF[LatestDF['Country'].isin(list(VaccineDF['Country']))]
VaccineDF = VaccineDF[VaccineDF['Country'].isin(list(CumulativeDF['Country']))] # to assure that they all have the same countries which is 190

CumulativeDF.reset_index(inplace=True, drop=True)
LatestDF.reset_index(inplace=True, drop=True)
VaccineDF.reset_index(inplace=True, drop=True)

print('DF1:',str(len(CumulativeDF['Country'].unique()))+', DF2:',str(len(LatestDF['Country']))+', DF3:',len(VaccineDF['Country']))
# Out:
# DF1: 189, DF2: 189, DF3: 189

# %%
merged_df2 = pd.merge(LatestDF, CumulativeDF, on=['Country'])
merged_df2 = pd.merge(merged_df2, VaccineDF, on=['Country'])

merged_df2['Date'] = pd.to_datetime(merged_df2['Date'])
print('merged_df2 countries:', len(merged_df2['Country'].unique()))
print('merged_df2 min date',min(merged_df2['Date']))
print('merged_df2 max date',max(merged_df2['Date']))
print(' ')

print(type(merged_df2.Date[0]))
# Out:
# merged_df2 countries: 189
# merged_df2 min date 2020-01-03 00:00:00
# merged_df2 max date 2022-09-15 00:00:00
#
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %% [markdown]
# ### Merging the 3 dataframes with the 24 dataframes

# %%
merged_df = pd.merge(merged_df2, merged_df, on=['Country','Date'])
merged_df = merged_df.sort_values(by='Date')
print('[merged_df]')
print('Countries:', len(merged_df['Country'].unique()))
print('Min date',min(merged_df['Date']))
print('Max date',max(merged_df['Date']))
print('Shape',merged_df.shape)
print(' ')
merged_df['Date']
# Out:
# [merged_df]
# Countries: 102
# Min date 2020-02-17 00:00:00
# Max date 2022-09-11 00:00:00
# Shape (93750, 56)
# 0       2020-02-17
# 72560   2020-02-17
# 71636   2020-02-17
# 6362    2020-02-17
# 70719   2020-02-17
#            ...
# 54117   2022-09-11
# 22146   2022-09-11
# 18437   2022-09-11
# 46670   2022-09-11
# 93749   2022-09-11
# Name: Date, Length: 93750, dtype: datetime64[ns]

# %%
print('Number of rows =', len(merged_df))
print('Number of columns =', len(merged_df.columns))
print('Number of countries =', len(merged_df['Country'].unique()))
print('Number of rows for each country =',len(merged_df)/len(merged_df['Country'].unique()))
print('With',merged_df.isna().sum().sum(),'Nulls')
print('Number of missing dates in the range between the min and max Dates =',
      len(pd.date_range(start=min(merged_df['Date']), end=max(merged_df['Date'])).difference(merged_df.Date)), '(No gaps in the date column)')
# Out:
# Number of rows = 93750
# Number of columns = 56
# Number of countries = 102
# Number of rows for each country = 919.1176470588235
# With 5241 Nulls
# Number of missing dates in the range between the min and max Dates = 0 (No gaps in the date column)

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 93750 entries, 0 to 93749
# Data columns (total 56 columns):
#  #   Column                                                        Non-Null Count  Dtype
# ---  ------                                                        --------------  -----
#  0   Country                                                       93750 non-null  object
#  1   Name                                                          93750 non-null  object
#  2   WHO Region                                                    93750 non-null  int64
#  3   Cases - cumulative total                                      93750 non-null  float64
#  4   Cases - cumulative total per 100000 population                93750 non-null  int64
#  5   Cases - newly reported in last 7 days                         93750 non-null  float64
#  6   Cases - newly reported in last 7 days per 100000 population   93750 non-null  int64
#  7   Cases - newly reported in last 24 hours                       93750 non-null  int64
#  8   Deaths - cumulative total                                     93750 non-null  float64
#  9   Deaths - cumulative total per 100000 population               93750 non-null  int64
#  10  Deaths - newly reported in last 7 days                        93750 non-null  float64
#  11  Deaths - newly reported in last 7 days per 100000 population  93750 non-null  int64
#  12  Date                                                          93750 non-null  datetime64[ns]
#  13  country code                                                  92847 non-null  object
#  14  WHO_region                                                    93750 non-null  object
#  15  New_cases                                                     93750 non-null  int64
#  16  Cumulative_cases                                              93750 non-null  int64
#  17  New_deaths                                                    93750 non-null  int64
#  18  Cumulative_deaths                                             93750 non-null  int64
#  19  ISO3                                                          93750 non-null  object
#  20  WHO_REGION                                                    93750 non-null  object
#  21  DATA_SOURCE                                                   93750 non-null  object
#  22  DATE_UPDATED                                                  93750 non-null  object
#  23  TOTAL_VACCINATIONS                                            93750 non-null  float64
#  24  PERSONS_VACCINATED_1PLUS_DOSE                                 93750 non-null  float64
#  25  TOTAL_VACCINATIONS_PER100                                     93750 non-null  float64
#  26  PERSONS_VACCINATED_1PLUS_DOSE_PER100                          93750 non-null  float64
#  27  PERSONS_FULLY_VACCINATED                                      93750 non-null  float64
#  28  PERSONS_FULLY_VACCINATED_PER100                               93750 non-null  float64
#  29  VACCINES_USED                                                 93750 non-null  object
#  30  FIRST_VACCINE_DATE                                            93750 non-null  object
#  31  NUMBER_VACCINES_TYPES_USED                                    93750 non-null  float64
#  32  PERSONS_BOOSTER_ADD_DOSE                                      93750 non-null  float64
#  33  PERSONS_BOOSTER_ADD_DOSE_PER100                               93750 non-null  float64
#  34  retail_and_recreation                                         92804 non-null  float64
#  35  grocery_and_pharmacy                                          92824 non-null  float64
#  36  residential                                                   92899 non-null  float64
#  37  transit_stations                                              93492 non-null  float64
#  38  parks                                                         92395 non-null  float64
#  39  workplaces                                                    93748 non-null  float64
#  40  debt_relief                                                   93750 non-null  int64
#  41  income_support                                                93750 non-null  int64
#  42  testing_policy                                                93750 non-null  int64
#  43  international_travel_controls                                 93750 non-null  int64
#  44  restrictions_internal_movements                               93750 non-null  int64
#  45  close_public_transport                                        93750 non-null  int64
#  46  stay_home_requirements                                        93750 non-null  int64
#  47  restriction_gatherings                                        93750 non-null  int64
#  48  cancel_public_events                                          93750 non-null  int64
#  49  workplace_closures                                            93750 non-null  int64
#  50  school_closures                                               93750 non-null  int64
#  51  containment_index                                             93750 non-null  float64
#  52  public_information_campaigns                                  93750 non-null  int64
#  53  facial_coverings                                              93750 non-null  int64
#  54  vaccine_availability                                          93750 non-null  int64
#  55  vaccination_policy                                            93750 non-null  int64
# dtypes: datetime64[ns](1), float64(20), int64(25), object(10)
# memory usage: 40.8+ MB

# %%
merged_df.reset_index(inplace=True)
merged_df.drop('index', inplace=True, axis=1)

# %% [markdown]
# # **Feature Engineering**

# %% [markdown]
# ### Added Day of the week
#
#
# *   Monday = 0
# *   Sunday = 6

# %%
merged_df['Day of the week'] = list(merged_df['Date'].dt.day_of_week)
merged_df['Day of the week string'] = list(merged_df['Date'].dt.day_name())
merged_df
# Out:
#           Country                   Name  WHO Region  \
# 0           India        South-East Asia    44516479
# 1      Kyrgyzstan                 Europe      205920
# 2      Mozambique                 Africa      230184
# 3       Australia        Western Pacific    10112229
# 4        Zimbabwe                 Africa      256939
# ...           ...                    ...         ...
# 93745      Latvia                 Europe      912002
# 93746        Peru               Americas     4127612
# 93747      Israel                 Europe     4646872
# 93748   Guatemala               Americas     1112550
# 93749       Yemen  Eastern Mediterranean       11932
#
#        Cases - cumulative total  \
# 0                      3225.822
# 1                      3156.253
# 2                       736.461
# 3                     39655.980
# 4                      1728.724
# ...                         ...
# 93745                 47806.990
# 93746                 12518.592
# 93747                 53686.673
# 93748                  6209.962
# 93749                    40.005
#
#        Cases - cumulative total per 100000 population  \
# 0                                               37843
# 1                                                  85
# 2                                                  39
# 3                                               17318
# 4                                                 105
# ...                                               ...
# 93745                                            7019
# 93746                                            8820
# 93747                                            7134
# 93748                                            6397
# 93749                                               1
#
#        Cases - newly reported in last 7 days  \
# 0                                      2.742
# 1                                      1.303
# 2                                      0.125
# 3                                     67.914
# 4                                      0.706
# ...                                      ...
# 93745                                367.935
# 93746                                 26.750
# 93747                                 82.421
# 93748                                 35.706
# 93749                                  0.003
#
#        Cases - newly reported in last 7 days per 100000 population  \
# 0                                                   6422
# 1                                                      0
# 2                                                      4
# 3                                                      0
# 4                                                      0
# ...                                                  ...
# 93745                                               1419
# 93746                                               1150
# 93747                                               1112
# 93748                                                  0
# 93749                                                  0
#
#        Cases - newly reported in last 24 hours  Deaths - cumulative total  \
# 0                                       528250                     38.279
# 1                                         2991                     45.845
# 2                                         2222                      7.109
# 3                                        14421                     56.553
# 4                                         5596                     37.651
# ...                                        ...                        ...
# 93745                                     5965                    312.684
# 93746                                   216173                    655.629
# 93747                                    11667                    134.792
# 93748                                    19684                    109.871
# 93749                                     2155                      7.225
#
#        Deaths - cumulative total per 100000 population  ...  \
# 0                                                  160  ...
# 1                                                    0  ...
# 2                                                    0  ...
# 3                                                  207  ...
# 4                                                    0  ...
# ...                                                ...  ...
# 93745                                                9  ...
# 93746                                              191  ...
# 93747                                                2  ...
# 93748                                              100  ...
# 93749                                                0  ...
#
#        cancel_public_events  workplace_closures school_closures  \
# 0                         0                   0               0
# 1                         0                   0               0
# 2                         0                   0               0
# 3                         0                   0               0
# 4                         0                   0               0
# ...                     ...                 ...             ...
# 93745                     0                   0               0
# 93746                     1                   1               1
# 93747                     0                   0               1
# 93748                     1                   1               2
# 93749                     1                   0               0
#
#       containment_index public_information_campaigns  facial_coverings  \
# 0                 17.26                            1                 0
# 1                 11.31                            2                 0
# 2                  5.36                            1                 0
# 3                 22.02                            2                 0
# 4                  5.36                            1                 0
# ...                 ...                          ...               ...
# 93745             22.62                            2                 2
# 93746             50.48                            2                 3
# 93747             36.90                            2                 2
# 93748             50.60                            2                 4
# 93749             13.10                            0                 0
#
#        vaccine_availability  vaccination_policy  Day of the week  \
# 0                         0                   0                0
# 1                         0                   0                0
# 2                         0                   0                0
# 3                         0                   0                0
# 4                         0                   0                0
# ...                     ...                 ...              ...
# 93745                     3                   5                6
# 93746                     0                   5                6
# 93747                     3                   5                6
# 93748                     3                   5                6
# 93749                     0                   5                6
#
#       Day of the week string
# 0                     Monday
# 1                     Monday
# 2                     Monday
# 3                     Monday
# 4                     Monday
# ...                      ...
# 93745                 Sunday
# 93746                 Sunday
# 93747                 Sunday
# 93748                 Sunday
# 93749                 Sunday
#
# [93750 rows x 58 columns]

# %% [markdown]
# ### Parsed the "Date" column into three more features
#
#
# *   Day
# *   Month
# *   Year

# %%
merged_df['Day'] = pd.to_datetime(merged_df['Date']).dt.day
merged_df['Month'] = pd.to_datetime(merged_df['Date']).dt.month
merged_df['Year'] = pd.to_datetime(merged_df['Date']).dt.year
merged_df
# Out:
#           Country                   Name  WHO Region  \
# 0           India        South-East Asia    44516479
# 1      Kyrgyzstan                 Europe      205920
# 2      Mozambique                 Africa      230184
# 3       Australia        Western Pacific    10112229
# 4        Zimbabwe                 Africa      256939
# ...           ...                    ...         ...
# 93745      Latvia                 Europe      912002
# 93746        Peru               Americas     4127612
# 93747      Israel                 Europe     4646872
# 93748   Guatemala               Americas     1112550
# 93749       Yemen  Eastern Mediterranean       11932
#
#        Cases - cumulative total  \
# 0                      3225.822
# 1                      3156.253
# 2                       736.461
# 3                     39655.980
# 4                      1728.724
# ...                         ...
# 93745                 47806.990
# 93746                 12518.592
# 93747                 53686.673
# 93748                  6209.962
# 93749                    40.005
#
#        Cases - cumulative total per 100000 population  \
# 0                                               37843
# 1                                                  85
# 2                                                  39
# 3                                               17318
# 4                                                 105
# ...                                               ...
# 93745                                            7019
# 93746                                            8820
# 93747                                            7134
# 93748                                            6397
# 93749                                               1
#
#        Cases - newly reported in last 7 days  \
# 0                                      2.742
# 1                                      1.303
# 2                                      0.125
# 3                                     67.914
# 4                                      0.706
# ...                                      ...
# 93745                                367.935
# 93746                                 26.750
# 93747                                 82.421
# 93748                                 35.706
# 93749                                  0.003
#
#        Cases - newly reported in last 7 days per 100000 population  \
# 0                                                   6422
# 1                                                      0
# 2                                                      4
# 3                                                      0
# 4                                                      0
# ...                                                  ...
# 93745                                               1419
# 93746                                               1150
# 93747                                               1112
# 93748                                                  0
# 93749                                                  0
#
#        Cases - newly reported in last 24 hours  Deaths - cumulative total  \
# 0                                       528250                     38.279
# 1                                         2991                     45.845
# 2                                         2222                      7.109
# 3                                        14421                     56.553
# 4                                         5596                     37.651
# ...                                        ...                        ...
# 93745                                     5965                    312.684
# 93746                                   216173                    655.629
# 93747                                    11667                    134.792
# 93748                                    19684                    109.871
# 93749                                     2155                      7.225
#
#        Deaths - cumulative total per 100000 population  ...  \
# 0                                                  160  ...
# 1                                                    0  ...
# 2                                                    0  ...
# 3                                                  207  ...
# 4                                                    0  ...
# ...                                                ...  ...
# 93745                                                9  ...
# 93746                                              191  ...
# 93747                                                2  ...
# 93748                                              100  ...
# 93749                                                0  ...
#
#        containment_index  public_information_campaigns facial_coverings  \
# 0                  17.26                             1                0
# 1                  11.31                             2                0
# 2                   5.36                             1                0
# 3                  22.02                             2                0
# 4                   5.36                             1                0
# ...                  ...                           ...              ...
# 93745              22.62                             2                2
# 93746              50.48                             2                3
# 93747              36.90                             2                2
# 93748              50.60                             2                4
# 93749              13.10                             0                0
#
#       vaccine_availability vaccination_policy  Day of the week  \
# 0                        0                  0                0
# 1                        0                  0                0
# 2                        0                  0                0
# 3                        0                  0                0
# 4                        0                  0                0
# ...                    ...                ...              ...
# 93745                    3                  5                6
# 93746                    0                  5                6
# 93747                    3                  5                6
# 93748                    3                  5                6
# 93749                    0                  5                6
#
#        Day of the week string  Day  Month  Year
# 0                      Monday   17      2  2020
# 1                      Monday   17      2  2020
# 2                      Monday   17      2  2020
# 3                      Monday   17      2  2020
# 4                      Monday   17      2  2020
# ...                       ...  ...    ...   ...
# 93745                  Sunday   11      9  2022
# 93746                  Sunday   11      9  2022
# 93747                  Sunday   11      9  2022
# 93748                  Sunday   11      9  2022
# 93749                  Sunday   11      9  2022
#
# [93750 rows x 61 columns]

# %% [markdown]
# ### Added weekend column

# %%
names = merged_df['Day of the week']
lst = []
for i in range(len(names)):
  if((names[i] == 5) or (names[i] == 6)):
    lst.append(1)
  else:
    lst.append(0)
    
merged_df['Weekend'] = lst
merged_df[merged_df['Weekend'] == 1]
# Out:
#             Country                   Name  WHO Region  \
# 510     Switzerland                 Europe     4053997
# 511           Libya  Eastern Mediterranean      506909
# 512          Latvia                 Europe      912002
# 513          Mexico               Americas     7059936
# 514    South Africa                 Africa     4014986
# ...             ...                    ...         ...
# 93745        Latvia                 Europe      912002
# 93746          Peru               Americas     4127612
# 93747        Israel                 Europe     4646872
# 93748     Guatemala               Americas     1112550
# 93749         Yemen  Eastern Mediterranean       11932
#
#        Cases - cumulative total  \
# 510                   46842.010
# 511                    7377.201
# 512                   47806.990
# 513                    5475.673
# 514                    6769.642
# ...                         ...
# 93745                 47806.990
# 93746                 12518.592
# 93747                 53686.673
# 93748                  6209.962
# 93749                    40.005
#
#        Cases - cumulative total per 100000 population  \
# 510                                              7840
# 511                                                31
# 512                                              7019
# 513                                              4301
# 514                                              2174
# ...                                               ...
# 93745                                            7019
# 93746                                            8820
# 93747                                            7134
# 93748                                            6397
# 93749                                               1
#
#        Cases - newly reported in last 7 days  \
# 510                                   90.587
# 511                                    0.451
# 512                                  367.935
# 513                                    3.336
# 514                                    3.666
# ...                                      ...
# 93745                                367.935
# 93746                                 26.750
# 93747                                 82.421
# 93748                                 35.706
# 93749                                  0.003
#
#        Cases - newly reported in last 7 days per 100000 population  \
# 510                                                    0
# 511                                                   20
# 512                                                 1419
# 513                                                    0
# 514                                                  262
# ...                                                  ...
# 93745                                               1419
# 93746                                               1150
# 93747                                               1112
# 93748                                                  0
# 93749                                                  0
#
#        Cases - newly reported in last 24 hours  Deaths - cumulative total  \
# 510                                      13550                    156.564
# 511                                       6437                     93.680
# 512                                       5965                    312.684
# 513                                     329767                    255.767
# 514                                     102129                    172.199
# ...                                        ...                        ...
# 93745                                     5965                    312.684
# 93746                                   216173                    655.629
# 93747                                    11667                    134.792
# 93748                                    19684                    109.871
# 93749                                     2155                      7.225
#
#        Deaths - cumulative total per 100000 population  ...  \
# 510                                                  1  ...
# 511                                                  0  ...
# 512                                                  9  ...
# 513                                                 24  ...
# 514                                                  0  ...
# ...                                                ...  ...
# 93745                                                9  ...
# 93746                                              191  ...
# 93747                                                2  ...
# 93748                                              100  ...
# 93749                                                0  ...
#
#        public_information_campaigns  facial_coverings vaccine_availability  \
# 510                               0                 0                    0
# 511                               0                 0                    0
# 512                               1                 0                    0
# 513                               0                 0                    0
# 514                               0                 0                    0
# ...                             ...               ...                  ...
# 93745                             2                 2                    3
# 93746                             2                 3                    0
# 93747                             2                 2                    3
# 93748                             2                 4                    3
# 93749                             0                 0                    0
#
#       vaccination_policy Day of the week  Day of the week string  Day  Month  \
# 510                    0               5                Saturday   22      2
# 511                    0               5                Saturday   22      2
# 512                    0               5                Saturday   22      2
# 513                    0               5                Saturday   22      2
# 514                    0               5                Saturday   22      2
# ...                  ...             ...                     ...  ...    ...
# 93745                  5               6                  Sunday   11      9
# 93746                  5               6                  Sunday   11      9
# 93747                  5               6                  Sunday   11      9
# 93748                  5               6                  Sunday   11      9
# 93749                  5               6                  Sunday   11      9
#
#        Year Weekend
# 510    2020       1
# 511    2020       1
# 512    2020       1
# 513    2020       1
# 514    2020       1
# ...     ...     ...
# 93745  2022       1
# 93746  2022       1
# 93747  2022       1
# 93748  2022       1
# 93749  2022       1
#
# [26723 rows x 62 columns]

# %% [markdown]
# ### Adding death ratio per country
#
#
# > Death Ratio = total number of deaths / total number of cases

# %%
DeathRatioDF = (merged_df.groupby('Country')['Deaths - cumulative total'].max()/merged_df.groupby('Country')['Cases - cumulative total'].max())*100
DeathRatioDF = DeathRatioDF.to_frame()
DeathRatioDF.reset_index(inplace=True)
DeathRatioDF = DeathRatioDF.rename(columns={0:'Death Ratio'})

merged_df = pd.merge(merged_df, DeathRatioDF, on=['Country'])
merged_df
# Out:
#       Country             Name  WHO Region  Cases - cumulative total  \
# 0       India  South-East Asia    44516479                  3225.822
# 1       India  South-East Asia    44516479                  3225.822
# 2       India  South-East Asia    44516479                  3225.822
# 3       India  South-East Asia    44516479                  3225.822
# 4       India  South-East Asia    44516479                  3225.822
# ...       ...              ...         ...                       ...
# 93745    Peru         Americas     4127612                 12518.592
# 93746    Peru         Americas     4127612                 12518.592
# 93747    Peru         Americas     4127612                 12518.592
# 93748    Peru         Americas     4127612                 12518.592
# 93749    Peru         Americas     4127612                 12518.592
#
#        Cases - cumulative total per 100000 population  \
# 0                                               37843
# 1                                               37843
# 2                                               37843
# 3                                               37843
# 4                                               37843
# ...                                               ...
# 93745                                            8820
# 93746                                            8820
# 93747                                            8820
# 93748                                            8820
# 93749                                            8820
#
#        Cases - newly reported in last 7 days  \
# 0                                      2.742
# 1                                      2.742
# 2                                      2.742
# 3                                      2.742
# 4                                      2.742
# ...                                      ...
# 93745                                 26.750
# 93746                                 26.750
# 93747                                 26.750
# 93748                                 26.750
# 93749                                 26.750
#
#        Cases - newly reported in last 7 days per 100000 population  \
# 0                                                   6422
# 1                                                   6422
# 2                                                   6422
# 3                                                   6422
# 4                                                   6422
# ...                                                  ...
# 93745                                               1150
# 93746                                               1150
# 93747                                               1150
# 93748                                               1150
# 93749                                               1150
#
#        Cases - newly reported in last 24 hours  Deaths - cumulative total  \
# 0                                       528250                     38.279
# 1                                       528250                     38.279
# 2                                       528250                     38.279
# 3                                       528250                     38.279
# 4                                       528250                     38.279
# ...                                        ...                        ...
# 93745                                   216173                    655.629
# 93746                                   216173                    655.629
# 93747                                   216173                    655.629
# 93748                                   216173                    655.629
# 93749                                   216173                    655.629
#
#        Deaths - cumulative total per 100000 population  ...  facial_coverings  \
# 0                                                  160  ...                 0
# 1                                                  160  ...                 0
# 2                                                  160  ...                 0
# 3                                                  160  ...                 0
# 4                                                  160  ...                 0
# ...                                                ...  ...               ...
# 93745                                              191  ...                 3
# 93746                                              191  ...                 3
# 93747                                              191  ...                 3
# 93748                                              191  ...                 3
# 93749                                              191  ...                 3
#
#        vaccine_availability vaccination_policy Day of the week  \
# 0                         0                  0               0
# 1                         0                  0               1
# 2                         0                  0               2
# 3                         0                  0               3
# 4                         0                  0               4
# ...                     ...                ...             ...
# 93745                     0                  5               2
# 93746                     0                  5               3
# 93747                     0                  5               4
# 93748                     0                  5               5
# 93749                     0                  5               6
#
#       Day of the week string  Day  Month  Year  Weekend Death Ratio
# 0                     Monday   17      2  2020        0    1.186643
# 1                    Tuesday   18      2  2020        0    1.186643
# 2                  Wednesday   19      2  2020        0    1.186643
# 3                   Thursday   20      2  2020        0    1.186643
# 4                     Friday   21      2  2020        0    1.186643
# ...                      ...  ...    ...   ...      ...         ...
# 93745              Wednesday    7      9  2022        0    5.237242
# 93746               Thursday    8      9  2022        0    5.237242
# 93747                 Friday    9      9  2022        0    5.237242
# 93748               Saturday   10      9  2022        1    5.237242
# 93749                 Sunday   11      9  2022        1    5.237242
#
# [93750 rows x 63 columns]

# %% [markdown]
# ### Adding continents and droping the name column

# %%
continents = []
countries = merged_df['Country'].unique()

for country in countries:
  country_code = pc.country_name_to_country_alpha2(country, cn_name_format="default")
  continent_name = pc.country_alpha2_to_continent_code(country_code)
  continents.append(continent_name)

continentsDic = {
    'NA': 'North America',
    'SA': 'South America', 
    'AS': 'Asia',
    'OC': 'Australia',
    'AF': 'Africa',
    'EU': 'Europe'
}

ContinentDF = pd.DataFrame(list(zip(countries,continents)), columns=['Country','Continent'])

for i in range(len(ContinentDF['Continent'])):
  ContinentDF['Continent'][i] = continentsDic[ContinentDF['Continent'][i]]
  

ContinentDF
# Out:
#         Country      Continent
# 0         India           Asia
# 1    Kyrgyzstan           Asia
# 2    Mozambique         Africa
# 3     Australia      Australia
# 4      Zimbabwe         Africa
# ..          ...            ...
# 97      Finland         Europe
# 98       Norway         Europe
# 99   Costa Rica  North America
# 100       Yemen           Asia
# 101        Peru  South America
#
# [102 rows x 2 columns]

# %%
merged_df = pd.merge(merged_df, ContinentDF, on=['Country'])
merged_df.drop('Name', axis=1,inplace=True)
merged_df
# Out:
#       Country  WHO Region  Cases - cumulative total  \
# 0       India    44516479                  3225.822
# 1       India    44516479                  3225.822
# 2       India    44516479                  3225.822
# 3       India    44516479                  3225.822
# 4       India    44516479                  3225.822
# ...       ...         ...                       ...
# 93745    Peru     4127612                 12518.592
# 93746    Peru     4127612                 12518.592
# 93747    Peru     4127612                 12518.592
# 93748    Peru     4127612                 12518.592
# 93749    Peru     4127612                 12518.592
#
#        Cases - cumulative total per 100000 population  \
# 0                                               37843
# 1                                               37843
# 2                                               37843
# 3                                               37843
# 4                                               37843
# ...                                               ...
# 93745                                            8820
# 93746                                            8820
# 93747                                            8820
# 93748                                            8820
# 93749                                            8820
#
#        Cases - newly reported in last 7 days  \
# 0                                      2.742
# 1                                      2.742
# 2                                      2.742
# 3                                      2.742
# 4                                      2.742
# ...                                      ...
# 93745                                 26.750
# 93746                                 26.750
# 93747                                 26.750
# 93748                                 26.750
# 93749                                 26.750
#
#        Cases - newly reported in last 7 days per 100000 population  \
# 0                                                   6422
# 1                                                   6422
# 2                                                   6422
# 3                                                   6422
# 4                                                   6422
# ...                                                  ...
# 93745                                               1150
# 93746                                               1150
# 93747                                               1150
# 93748                                               1150
# 93749                                               1150
#
#        Cases - newly reported in last 24 hours  Deaths - cumulative total  \
# 0                                       528250                     38.279
# 1                                       528250                     38.279
# 2                                       528250                     38.279
# 3                                       528250                     38.279
# 4                                       528250                     38.279
# ...                                        ...                        ...
# 93745                                   216173                    655.629
# 93746                                   216173                    655.629
# 93747                                   216173                    655.629
# 93748                                   216173                    655.629
# 93749                                   216173                    655.629
#
#        Deaths - cumulative total per 100000 population  \
# 0                                                  160
# 1                                                  160
# 2                                                  160
# 3                                                  160
# 4                                                  160
# ...                                                ...
# 93745                                              191
# 93746                                              191
# 93747                                              191
# 93748                                              191
# 93749                                              191
#
#        Deaths - newly reported in last 7 days  ...  vaccine_availability  \
# 0                                       0.012  ...                     0
# 1                                       0.012  ...                     0
# 2                                       0.012  ...                     0
# 3                                       0.012  ...                     0
# 4                                       0.012  ...                     0
# ...                                       ...  ...                   ...
# 93745                                   0.579  ...                     0
# 93746                                   0.579  ...                     0
# 93747                                   0.579  ...                     0
# 93748                                   0.579  ...                     0
# 93749                                   0.579  ...                     0
#
#       vaccination_policy Day of the week Day of the week string  Day  Month  \
# 0                      0               0                 Monday   17      2
# 1                      0               1                Tuesday   18      2
# 2                      0               2              Wednesday   19      2
# 3                      0               3               Thursday   20      2
# 4                      0               4                 Friday   21      2
# ...                  ...             ...                    ...  ...    ...
# 93745                  5               2              Wednesday    7      9
# 93746                  5               3               Thursday    8      9
# 93747                  5               4                 Friday    9      9
# 93748                  5               5               Saturday   10      9
# 93749                  5               6                 Sunday   11      9
#
#        Year  Weekend Death Ratio      Continent
# 0      2020        0    1.186643           Asia
# 1      2020        0    1.186643           Asia
# 2      2020        0    1.186643           Asia
# 3      2020        0    1.186643           Asia
# 4      2020        0    1.186643           Asia
# ...     ...      ...         ...            ...
# 93745  2022        0    5.237242  South America
# 93746  2022        0    5.237242  South America
# 93747  2022        0    5.237242  South America
# 93748  2022        1    5.237242  South America
# 93749  2022        1    5.237242  South America
#
# [93750 rows x 63 columns]

# %% [markdown]
# ### Added Longutude and Latitude

# %%
geolocator = Nominatim()
def geolocate(country):
    try:
        # Geolocate the center of the country
        loc = geolocator.geocode(country)
        # And return latitude and longitude
        return (loc.latitude, loc.longitude)
    except:
        # Return missing value
        return np.nan

countries = merged_df['Country'].unique()
lat=[]
lng=[]
for country in countries:
  lat.append(geolocate(country)[0])
  lng.append(geolocate(country)[1])

CountryDF = pd.DataFrame(list(zip(countries,lat,lng)), columns=['Country','latitude','longitude'])
CountryDF
# Out:
#         Country   latitude   longitude
# 0         India  22.351115   78.667743
# 1    Kyrgyzstan  41.508932   74.724091
# 2    Mozambique -19.302233   34.914498
# 3     Australia -24.776109  134.755000
# 4      Zimbabwe -18.455496   29.746841
# ..          ...        ...         ...
# 97      Finland  63.246778   25.920916
# 98       Norway  60.500021    9.099972
# 99   Costa Rica  10.273563  -84.073910
# 100       Yemen  16.347124   47.891527
# 101        Peru  -6.869970  -75.045851
#
# [102 rows x 3 columns]

# %%
merged_df = pd.merge(merged_df, CountryDF, on=['Country'])
print('With',merged_df.isna().sum().sum(),'Nulls')
merged_df
# Out:
# With 5241 Nulls
#       Country  WHO Region  Cases - cumulative total  \
# 0       India    44516479                  3225.822
# 1       India    44516479                  3225.822
# 2       India    44516479                  3225.822
# 3       India    44516479                  3225.822
# 4       India    44516479                  3225.822
# ...       ...         ...                       ...
# 93745    Peru     4127612                 12518.592
# 93746    Peru     4127612                 12518.592
# 93747    Peru     4127612                 12518.592
# 93748    Peru     4127612                 12518.592
# 93749    Peru     4127612                 12518.592
#
#        Cases - cumulative total per 100000 population  \
# 0                                               37843
# 1                                               37843
# 2                                               37843
# 3                                               37843
# 4                                               37843
# ...                                               ...
# 93745                                            8820
# 93746                                            8820
# 93747                                            8820
# 93748                                            8820
# 93749                                            8820
#
#        Cases - newly reported in last 7 days  \
# 0                                      2.742
# 1                                      2.742
# 2                                      2.742
# 3                                      2.742
# 4                                      2.742
# ...                                      ...
# 93745                                 26.750
# 93746                                 26.750
# 93747                                 26.750
# 93748                                 26.750
# 93749                                 26.750
#
#        Cases - newly reported in last 7 days per 100000 population  \
# 0                                                   6422
# 1                                                   6422
# 2                                                   6422
# 3                                                   6422
# 4                                                   6422
# ...                                                  ...
# 93745                                               1150
# 93746                                               1150
# 93747                                               1150
# 93748                                               1150
# 93749                                               1150
#
#        Cases - newly reported in last 24 hours  Deaths - cumulative total  \
# 0                                       528250                     38.279
# 1                                       528250                     38.279
# 2                                       528250                     38.279
# 3                                       528250                     38.279
# 4                                       528250                     38.279
# ...                                        ...                        ...
# 93745                                   216173                    655.629
# 93746                                   216173                    655.629
# 93747                                   216173                    655.629
# 93748                                   216173                    655.629
# 93749                                   216173                    655.629
#
#        Deaths - cumulative total per 100000 population  \
# 0                                                  160
# 1                                                  160
# 2                                                  160
# 3                                                  160
# 4                                                  160
# ...                                                ...
# 93745                                              191
# 93746                                              191
# 93747                                              191
# 93748                                              191
# 93749                                              191
#
#        Deaths - newly reported in last 7 days  ...  Day of the week  \
# 0                                       0.012  ...                0
# 1                                       0.012  ...                1
# 2                                       0.012  ...                2
# 3                                       0.012  ...                3
# 4                                       0.012  ...                4
# ...                                       ...  ...              ...
# 93745                                   0.579  ...                2
# 93746                                   0.579  ...                3
# 93747                                   0.579  ...                4
# 93748                                   0.579  ...                5
# 93749                                   0.579  ...                6
#
#       Day of the week string Day Month  Year  Weekend  Death Ratio  \
# 0                     Monday  17     2  2020        0     1.186643
# 1                    Tuesday  18     2  2020        0     1.186643
# 2                  Wednesday  19     2  2020        0     1.186643
# 3                   Thursday  20     2  2020        0     1.186643
# 4                     Friday  21     2  2020        0     1.186643
# ...                      ...  ..   ...   ...      ...          ...
# 93745              Wednesday   7     9  2022        0     5.237242
# 93746               Thursday   8     9  2022        0     5.237242
# 93747                 Friday   9     9  2022        0     5.237242
# 93748               Saturday  10     9  2022        1     5.237242
# 93749                 Sunday  11     9  2022        1     5.237242
#
#            Continent   latitude  longitude
# 0               Asia  22.351115  78.667743
# 1               Asia  22.351115  78.667743
# 2               Asia  22.351115  78.667743
# 3               Asia  22.351115  78.667743
# 4               Asia  22.351115  78.667743
# ...              ...        ...        ...
# 93745  South America  -6.869970 -75.045851
# 93746  South America  -6.869970 -75.045851
# 93747  South America  -6.869970 -75.045851
# 93748  South America  -6.869970 -75.045851
# 93749  South America  -6.869970 -75.045851
#
# [93750 rows x 65 columns]

# %%
merged_df.dropna(inplace=True)
merged_df.reset_index(inplace=True)
merged_df.drop('index',axis=1,inplace=True)
merged_df
# Out:
#       Country  WHO Region  Cases - cumulative total  \
# 0       India    44516479                  3225.822
# 1       India    44516479                  3225.822
# 2       India    44516479                  3225.822
# 3       India    44516479                  3225.822
# 4       India    44516479                  3225.822
# ...       ...         ...                       ...
# 91461    Peru     4127612                 12518.592
# 91462    Peru     4127612                 12518.592
# 91463    Peru     4127612                 12518.592
# 91464    Peru     4127612                 12518.592
# 91465    Peru     4127612                 12518.592
#
#        Cases - cumulative total per 100000 population  \
# 0                                               37843
# 1                                               37843
# 2                                               37843
# 3                                               37843
# 4                                               37843
# ...                                               ...
# 91461                                            8820
# 91462                                            8820
# 91463                                            8820
# 91464                                            8820
# 91465                                            8820
#
#        Cases - newly reported in last 7 days  \
# 0                                      2.742
# 1                                      2.742
# 2                                      2.742
# 3                                      2.742
# 4                                      2.742
# ...                                      ...
# 91461                                 26.750
# 91462                                 26.750
# 91463                                 26.750
# 91464                                 26.750
# 91465                                 26.750
#
#        Cases - newly reported in last 7 days per 100000 population  \
# 0                                                   6422
# 1                                                   6422
# 2                                                   6422
# 3                                                   6422
# 4                                                   6422
# ...                                                  ...
# 91461                                               1150
# 91462                                               1150
# 91463                                               1150
# 91464                                               1150
# 91465                                               1150
#
#        Cases - newly reported in last 24 hours  Deaths - cumulative total  \
# 0                                       528250                     38.279
# 1                                       528250                     38.279
# 2                                       528250                     38.279
# 3                                       528250                     38.279
# 4                                       528250                     38.279
# ...                                        ...                        ...
# 91461                                   216173                    655.629
# 91462                                   216173                    655.629
# 91463                                   216173                    655.629
# 91464                                   216173                    655.629
# 91465                                   216173                    655.629
#
#        Deaths - cumulative total per 100000 population  \
# 0                                                  160
# 1                                                  160
# 2                                                  160
# 3                                                  160
# 4                                                  160
# ...                                                ...
# 91461                                              191
# 91462                                              191
# 91463                                              191
# 91464                                              191
# 91465                                              191
#
#        Deaths - newly reported in last 7 days  ...  Day of the week  \
# 0                                       0.012  ...                0
# 1                                       0.012  ...                1
# 2                                       0.012  ...                2
# 3                                       0.012  ...                3
# 4                                       0.012  ...                4
# ...                                       ...  ...              ...
# 91461                                   0.579  ...                2
# 91462                                   0.579  ...                3
# 91463                                   0.579  ...                4
# 91464                                   0.579  ...                5
# 91465                                   0.579  ...                6
#
#       Day of the week string Day Month  Year  Weekend  Death Ratio  \
# 0                     Monday  17     2  2020        0     1.186643
# 1                    Tuesday  18     2  2020        0     1.186643
# 2                  Wednesday  19     2  2020        0     1.186643
# 3                   Thursday  20     2  2020        0     1.186643
# 4                     Friday  21     2  2020        0     1.186643
# ...                      ...  ..   ...   ...      ...          ...
# 91461              Wednesday   7     9  2022        0     5.237242
# 91462               Thursday   8     9  2022        0     5.237242
# 91463                 Friday   9     9  2022        0     5.237242
# 91464               Saturday  10     9  2022        1     5.237242
# 91465                 Sunday  11     9  2022        1     5.237242
#
#            Continent   latitude  longitude
# 0               Asia  22.351115  78.667743
# 1               Asia  22.351115  78.667743
# 2               Asia  22.351115  78.667743
# 3               Asia  22.351115  78.667743
# 4               Asia  22.351115  78.667743
# ...              ...        ...        ...
# 91461  South America  -6.869970 -75.045851
# 91462  South America  -6.869970 -75.045851
# 91463  South America  -6.869970 -75.045851
# 91464  South America  -6.869970 -75.045851
# 91465  South America  -6.869970 -75.045851
#
# [91466 rows x 65 columns]

# %% [markdown]
# ### Adding population, area, and density of each country.

# %%
PopulationDF = pd.read_csv('/content/drive/MyDrive/COVID 19 Data/World_Population_Review/population-area-density.csv')
PopulationDF.rename(columns={'name':'Country'}, inplace=True)
PopulationDF
# Out:
#      Rank        Country      pop2022      pop2021  GrowthRate     area  \
# 0       1          China  1425887.337  1425893.465      1.0000  9706961
# 1       2          India  1417173.173  1407563.842      1.0068  3287590
# 2       3  United States   338289.857   336997.624      1.0038  9372610
# 3       4      Indonesia   275501.339   273753.191      1.0064  1904569
# 4       5       Pakistan   235824.862   231402.117      1.0191   881912
# ..    ...            ...          ...          ...         ...      ...
# 205   206     San Marino       33.660       33.745      0.9975       61
# 206   207          Palau       18.055       18.024      1.0017      459
# 207   208          Nauru       12.668       12.511      1.0125       21
# 208   209         Tuvalu       11.312       11.204      1.0096       26
# 209   210   Vatican City        0.510        0.511      0.9980        1
#
#       Density
# 0    146.8933
# 1    431.0675
# 2     36.0935
# 3    144.6529
# 4    267.4018
# ..        ...
# 205  551.8033
# 206   39.3355
# 207  603.2381
# 208  435.0769
# 209  510.0000
#
# [210 rows x 7 columns]

# %%
merged_df = pd.merge(merged_df, PopulationDF, on=['Country'])
merged_df
# Out:
#       Country  WHO Region  Cases - cumulative total  \
# 0       India    44516479                  3225.822
# 1       India    44516479                  3225.822
# 2       India    44516479                  3225.822
# 3       India    44516479                  3225.822
# 4       India    44516479                  3225.822
# ...       ...         ...                       ...
# 90584    Peru     4127612                 12518.592
# 90585    Peru     4127612                 12518.592
# 90586    Peru     4127612                 12518.592
# 90587    Peru     4127612                 12518.592
# 90588    Peru     4127612                 12518.592
#
#        Cases - cumulative total per 100000 population  \
# 0                                               37843
# 1                                               37843
# 2                                               37843
# 3                                               37843
# 4                                               37843
# ...                                               ...
# 90584                                            8820
# 90585                                            8820
# 90586                                            8820
# 90587                                            8820
# 90588                                            8820
#
#        Cases - newly reported in last 7 days  \
# 0                                      2.742
# 1                                      2.742
# 2                                      2.742
# 3                                      2.742
# 4                                      2.742
# ...                                      ...
# 90584                                 26.750
# 90585                                 26.750
# 90586                                 26.750
# 90587                                 26.750
# 90588                                 26.750
#
#        Cases - newly reported in last 7 days per 100000 population  \
# 0                                                   6422
# 1                                                   6422
# 2                                                   6422
# 3                                                   6422
# 4                                                   6422
# ...                                                  ...
# 90584                                               1150
# 90585                                               1150
# 90586                                               1150
# 90587                                               1150
# 90588                                               1150
#
#        Cases - newly reported in last 24 hours  Deaths - cumulative total  \
# 0                                       528250                     38.279
# 1                                       528250                     38.279
# 2                                       528250                     38.279
# 3                                       528250                     38.279
# 4                                       528250                     38.279
# ...                                        ...                        ...
# 90584                                   216173                    655.629
# 90585                                   216173                    655.629
# 90586                                   216173                    655.629
# 90587                                   216173                    655.629
# 90588                                   216173                    655.629
#
#        Deaths - cumulative total per 100000 population  \
# 0                                                  160
# 1                                                  160
# 2                                                  160
# 3                                                  160
# 4                                                  160
# ...                                                ...
# 90584                                              191
# 90585                                              191
# 90586                                              191
# 90587                                              191
# 90588                                              191
#
#        Deaths - newly reported in last 7 days  ...  Death Ratio  \
# 0                                       0.012  ...     1.186643
# 1                                       0.012  ...     1.186643
# 2                                       0.012  ...     1.186643
# 3                                       0.012  ...     1.186643
# 4                                       0.012  ...     1.186643
# ...                                       ...  ...          ...
# 90584                                   0.579  ...     5.237242
# 90585                                   0.579  ...     5.237242
# 90586                                   0.579  ...     5.237242
# 90587                                   0.579  ...     5.237242
# 90588                                   0.579  ...     5.237242
#
#            Continent   latitude  longitude  Rank      pop2022      pop2021  \
# 0               Asia  22.351115  78.667743     2  1417173.173  1407563.842
# 1               Asia  22.351115  78.667743     2  1417173.173  1407563.842
# 2               Asia  22.351115  78.667743     2  1417173.173  1407563.842
# 3               Asia  22.351115  78.667743     2  1417173.173  1407563.842
# 4               Asia  22.351115  78.667743     2  1417173.173  1407563.842
# ...              ...        ...        ...   ...          ...          ...
# 90584  South America  -6.869970 -75.045851    45    34049.588    33715.471
# 90585  South America  -6.869970 -75.045851    45    34049.588    33715.471
# 90586  South America  -6.869970 -75.045851    45    34049.588    33715.471
# 90587  South America  -6.869970 -75.045851    45    34049.588    33715.471
# 90588  South America  -6.869970 -75.045851    45    34049.588    33715.471
#
#        GrowthRate     area   Density
# 0          1.0068  3287590  431.0675
# 1          1.0068  3287590  431.0675
# 2          1.0068  3287590  431.0675
# 3          1.0068  3287590  431.0675
# 4          1.0068  3287590  431.0675
# ...           ...      ...       ...
# 90584      1.0099  1285216   26.4933
# 90585      1.0099  1285216   26.4933
# 90586      1.0099  1285216   26.4933
# 90587      1.0099  1285216   26.4933
# 90588      1.0099  1285216   26.4933
#
# [90589 rows x 71 columns]

# %%
print('Number of rows =', len(merged_df))
print('Number of columns =', len(merged_df.columns))
print('Number of countries =', len(merged_df['Country'].unique()))
print('Number of rows for each country =',len(merged_df)/len(merged_df['Country'].unique()))
print('With',merged_df.isna().sum().sum(),'Nulls')
print('Number of missing dates in the range between the min and max Dates =',
      len(pd.date_range(start=min(merged_df['Date']), end=max(merged_df['Date'])).difference(merged_df.Date)), '(No gaps in the date column)')
# Out:
# Number of rows = 90589
# Number of columns = 71
# Number of countries = 99
# Number of rows for each country = 915.040404040404
# With 0 Nulls
# Number of missing dates in the range between the min and max Dates = 0 (No gaps in the date column)

# %% [markdown]
# ### Adding
# *   Life expectancy
# *   Sub-region
# *   Income group
# *   Rural percentage
# *   Temperature
# *   Time zone
# *   Poverty ratio
# *   Health care index
#
# **Important: Some column names and formating were changed using Excel before making the csv! Make sure to change the column names in Excel after downloading the data from the sources we've listed. If you struggle to obtain the data just email us or contact us on LinkedIn and we will send all the data.**

# %%
life = pd.read_csv('/content/drive/MyDrive/COVID 19 Data/Worldometers/life_expectancy.csv')
sub_region = pd.read_csv('/content/drive/MyDrive/COVID 19 Data/GitHub/sub-region.csv')
income = pd.read_csv('/content/drive/MyDrive/COVID 19 Data/The_World_Bank/income.csv')
rural = pd.read_csv('/content/drive/MyDrive/COVID 19 Data/The_World_Bank/rural-percentage.csv')
temp = pd.read_csv('/content/drive/MyDrive/COVID 19 Data/listfist/temperature.csv')


time_zone = pd.read_excel('/content/drive/MyDrive/COVID 19 Data/Wikipedia/time-zone.xlsx')
time_zone.dropna(inplace=True)
time_zone.reset_index(inplace=True)
time_zone.drop('index', axis=1, inplace=True)
time_zone = time_zone.astype({"No. of time zones": int})
time_zone['country'] = time_zone['country'].str.strip()

poverty = pd.read_csv('/content/drive/MyDrive/COVID 19 Data/World_Population_Review/poverty.csv')
poverty.rename(columns={'percPoverty':'poverty percentage '}, inplace=True)

#health = pd.read_csv('/content/drive/MyDrive/COVID 19 Data/Numbeo/health-care.csv')
health = pd.read_csv('/content/csvData (6).csv')

# %% [markdown]
# **column names after changing them using Excel**

# %%
print('life expectancy columns: ',list(life.columns))
print('sub_region columns: ',list(sub_region.columns))
print('income columns: ',list(income.columns))
print('rural columns: ',list(rural.columns))
print('temperature columns: ',list(temp.columns))
print('time_zone columns: ',list(time_zone.columns))
print('poverty columns: ',list(poverty.columns))
print('Health care columns: ',list(health.columns))
# Out:
# life expectancy columns:  ['country', 'Life Expectancy(both sexes) ', 'Life Expectancy(Females)', 'Life Expectancy(Males)']
# sub_region columns:  ['country', 'sub-region']
# income columns:  ['country', 'Income group']
# rural columns:  ['country', 'country code', 'rural percentage(2021)']
# temperature columns:  ['country', 'Average Temperature(1991-2020) C', 'Coldest Month(1991-2020) C', 'Hottest Month(1991-2020) C', 'Variation(1991-2020) C']
# time_zone columns:  ['country', 'No. of time zones', 'Time zone']
# poverty columns:  ['country', 'poverty percentage ']
# Health care columns:  ['country', 'legatumRank2020', 'legatumRank2019', 'ceoworldRank']

# %%
rural.drop('country code', axis=1, inplace=True)
merged_df.rename(columns={'Country':'country'}, inplace=True)

# %%
merged_df = pd.merge(merged_df, life, on=['country'])
merged_df = pd.merge(merged_df, sub_region, on=['country'])
merged_df = pd.merge(merged_df, income, on=['country'])
merged_df = pd.merge(merged_df, rural, on=['country'])
merged_df = pd.merge(merged_df, temp, on=['country'])
merged_df = pd.merge(merged_df, time_zone, on=['country'])
merged_df = pd.merge(merged_df, poverty, on=['country'])
merged_df = pd.merge(merged_df, health, on=['country'])

# %%
print('Number of rows =', len(merged_df))
print('Number of columns =', len(merged_df.columns))
print('Number of countries =', len(merged_df['country'].unique()))
print('Number of rows for each country =',len(merged_df)/len(merged_df['country'].unique()))
print('With',merged_df.isna().sum().sum(),'Nulls')
print('Number of missing dates in the range between the min and max Dates =',
      len(pd.date_range(start=min(merged_df['Date']), end=max(merged_df['Date'])).difference(merged_df.Date)), '(No gaps in the date column)')
# Out:
# Number of rows = 76831
# Number of columns = 87
# Number of countries = 84
# Number of rows for each country = 914.6547619047619
# With 26363 Nulls
# Number of missing dates in the range between the min and max Dates = 0 (No gaps in the date column)

# %% [markdown]
# # Cleaning
#
#
# *   Renamed some Countries
# *   Droppped a country with null data "Turkmenistan"
# *   Dropped some redundant features ( "country code, ”   who_region.1", “who region”, "rank", "data_source")
# *   Dropped missing values <1k
# *   Dropped “ceoworldRank” feature because it has 24k missing values around 32% of the entire dataset
# *   Converted all feature names into lower case

# %%
merged_df['country'] = merged_df['country'].replace('Israel', 'Palestine')

# %%
merged_df = merged_df[merged_df.country != 'Turkmenistan']
merged_df = merged_df.sort_values(by='Date')

# %%
for column in merged_df:
  merged_df.rename(columns={column:column.lower()}, inplace=True)
merged_df
# Out:
#           country  who region  cases - cumulative total  \
# 0           India    44516479                  3225.822
# 57460      Latvia      912002                 47806.990
# 56528    Paraguay      715806                 10035.782
# 55597    Malaysia     4811327                 14865.375
# 54690  Kazakhstan     1482094                  7893.258
# ...           ...         ...                       ...
# 60220      Poland     6233117                 16421.029
# 58397      Latvia      912002                 47806.990
# 61157     Uruguay      982846                 28293.679
# 52870      Canada     4197701                 11122.049
# 76830        Peru     4127612                 12518.592
#
#        cases - cumulative total per 100000 population  \
# 0                                               37843
# 57460                                            7019
# 56528                                             237
# 55597                                           13890
# 54690                                            1232
# ...                                               ...
# 60220                                           30681
# 58397                                            7019
# 61157                                            1660
# 52870                                           18365
# 76830                                            8820
#
#        cases - newly reported in last 7 days  \
# 0                                      2.742
# 57460                                367.935
# 56528                                  3.323
# 55597                                 42.915
# 54690                                  6.561
# ...                                      ...
# 60220                                 80.829
# 58397                                367.935
# 61157                                 47.787
# 52870                                 48.659
# 76830                                 26.750
#
#        cases - newly reported in last 7 days per 100000 population  \
# 0                                                   6422
# 57460                                               1419
# 56528                                                  0
# 55597                                               2431
# 54690                                                181
# ...                                                  ...
# 60220                                               5858
# 58397                                               1419
# 61157                                                  0
# 52870                                                  0
# 76830                                               1150
#
#        cases - newly reported in last 24 hours  deaths - cumulative total  \
# 0                                       528250                     38.279
# 57460                                     5965                    312.684
# 56528                                    19530                    273.816
# 55597                                    36296                    112.142
# 54690                                    19047                    101.440
# ...                                        ...                        ...
# 60220                                   117316                    309.067
# 58397                                     5965                    312.684
# 61157                                     7462                    214.812
# 52870                                    44347                    117.500
# 76830                                   216173                    655.629
#
#        deaths - cumulative total per 100000 population  \
# 0                                                  160
# 57460                                                9
# 56528                                               36
# 55597                                               34
# 54690                                                4
# ...                                                ...
# 60220                                               97
# 58397                                                9
# 61157                                                7
# 52870                                              237
# 76830                                              191
#
#        deaths - newly reported in last 7 days  ...  \
# 0                                       0.012  ...
# 57460                                   0.472  ...
# 56528                                   0.505  ...
# 55597                                   0.105  ...
# 54690                                   0.021  ...
# ...                                       ...  ...
# 60220                                   0.256  ...
# 58397                                   0.472  ...
# 61157                                   0.202  ...
# 52870                                   0.628  ...
# 76830                                   0.579  ...
#
#        average temperature(1991-2020) c coldest month(1991-2020) c  \
# 0                                 24.68                       16.3
# 57460                              6.86                      -10.9
# 56528                             23.73                       15.0
# 55597                             25.75                       24.5
# 54690                              6.91                      -18.0
# ...                                 ...                        ...
# 60220                              8.85                       -6.7
# 58397                              6.86                      -10.9
# 61157                             17.93                        8.8
# 52870                             -6.36                      -27.6
# 76830                             19.70                       17.6
#
#       hottest month(1991-2020) c variation(1991-2020) c  no. of time zones  \
# 0                           31.1                   14.8                  1
# 57460                       21.0                   31.9                  1
# 56528                       28.9                   13.9                  1
# 55597                       27.2                    2.7                  1
# 54690                       25.5                   43.5                  2
# ...                          ...                    ...                ...
# 60220                       21.3                   28.0                  1
# 58397                       21.0                   31.9                  1
# 61157                       25.8                   17.0                  1
# 52870                       12.8                   40.4                  6
# 76830                       21.7                    4.1                  1
#
#                                                time zone  poverty percentage   \
# 0                                        UTC+05:30 (IST)                 21.9
# 57460                                    UTC+02:00 (EET)                 22.9
# 56528                                          UTC−04:00                 23.5
# 55597                UTC+08:00 (Malaysian Standard Time)                  5.6
# 54690  UTC+05:00 — western Kazakhstan (Aktobe, Atyrau...                  4.3
# ...                                                  ...                  ...
# 60220                                    UTC+01:00 (CET)                 15.4
# 58397                                    UTC+02:00 (EET)                 22.9
# 61157                                          UTC−03:00                  8.8
# 52870  UTC−08:00 (PT) — larger western part of Britis...                 11.6
# 76830                                    UTC−05:00 (PET)                 20.2
#
#        legatumrank2020 legatumrank2019 ceoworldrank
# 0                  101              98         19.0
# 57460               32              32         48.0
# 56528               79              78          NaN
# 55597               40              42         34.0
# 54690               62              66         82.0
# ...                ...             ...          ...
# 60220               36              36         51.0
# 58397               32              32         48.0
# 61157               39              39         39.0
# 52870               14              13         23.0
# 76830               61              57         62.0
#
# [76831 rows x 87 columns]

# %%
merged_df.ceoworldrank.isna().sum()
# Out:
# 24531

# %%
merged_df.drop(['country code','rank', 'data_source','vaccine_availability','ceoworldrank','who region'],axis=1,inplace=True)

# %%
print('Missing Vlaues: ',merged_df.isna().sum().sum())
merged_df.dropna(inplace=True)
# Out:
# Missing Vlaues:  1832

# %%
print('Number of rows =', len(merged_df))
print('Number of columns =', len(merged_df.columns))
print('Number of countries =', len(merged_df['country'].unique()))
print('Number of rows for each country =',len(merged_df)/len(merged_df['country'].unique()))
print('With',merged_df.isna().sum().sum(),'Nulls')
print('Number of missing dates in the range between the min and max Dates =',
      len(pd.date_range(start=min(merged_df['date']), end=max(merged_df['date'])).difference(merged_df.date)), '(No gaps in the date column)')
# Out:
# Number of rows = 74999
# Number of columns = 81
# Number of countries = 82
# Number of rows for each country = 914.6219512195122
# With 0 Nulls
# Number of missing dates in the range between the min and max Dates = 0 (No gaps in the date column)

# %% [markdown]
# # Saving the DataFrame as csv.

# %%
merged_df = merged_df.sort_values(by='date')
merged_df.to_csv('COVID19_Data.csv')

# %%
merged_df.isnull().sum().sum()
# Out:
# 0

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 74999 entries, 0 to 76830
# Data columns (total 81 columns):
#  #   Column                                                        Non-Null Count  Dtype
# ---  ------                                                        --------------  -----
#  0   country                                                       74999 non-null  object
#  1   cases - cumulative total                                      74999 non-null  float64
#  2   cases - cumulative total per 100000 population                74999 non-null  int64
#  3   cases - newly reported in last 7 days                         74999 non-null  float64
#  4   cases - newly reported in last 7 days per 100000 population   74999 non-null  int64
#  5   cases - newly reported in last 24 hours                       74999 non-null  int64
#  6   deaths - cumulative total                                     74999 non-null  float64
#  7   deaths - cumulative total per 100000 population               74999 non-null  int64
#  8   deaths - newly reported in last 7 days                        74999 non-null  float64
#  9   deaths - newly reported in last 7 days per 100000 population  74999 non-null  int64
#  10  date                                                          74999 non-null  datetime64[ns]
#  11  who_region                                                    74999 non-null  object
#  12  new_cases                                                     74999 non-null  int64
#  13  cumulative_cases                                              74999 non-null  int64
#  14  new_deaths                                                    74999 non-null  int64
#  15  cumulative_deaths                                             74999 non-null  int64
#  16  iso3                                                          74999 non-null  object
#  17  who_region                                                    74999 non-null  object
#  18  date_updated                                                  74999 non-null  object
#  19  total_vaccinations                                            74999 non-null  float64
#  20  persons_vaccinated_1plus_dose                                 74999 non-null  float64
#  21  total_vaccinations_per100                                     74999 non-null  float64
#  22  persons_vaccinated_1plus_dose_per100                          74999 non-null  float64
#  23  persons_fully_vaccinated                                      74999 non-null  float64
#  24  persons_fully_vaccinated_per100                               74999 non-null  float64
#  25  vaccines_used                                                 74999 non-null  object
#  26  first_vaccine_date                                            74999 non-null  object
#  27  number_vaccines_types_used                                    74999 non-null  float64
#  28  persons_booster_add_dose                                      74999 non-null  float64
#  29  persons_booster_add_dose_per100                               74999 non-null  float64
#  30  retail_and_recreation                                         74999 non-null  float64
#  31  grocery_and_pharmacy                                          74999 non-null  float64
#  32  residential                                                   74999 non-null  float64
#  33  transit_stations                                              74999 non-null  float64
#  34  parks                                                         74999 non-null  float64
#  35  workplaces                                                    74999 non-null  float64
#  36  debt_relief                                                   74999 non-null  int64
#  37  income_support                                                74999 non-null  int64
#  38  testing_policy                                                74999 non-null  int64
#  39  international_travel_controls                                 74999 non-null  object
#  40  restrictions_internal_movements                               74999 non-null  object
#  41  close_public_transport                                        74999 non-null  object
#  42  stay_home_requirements                                        74999 non-null  object
#  43  restriction_gatherings                                        74999 non-null  object
#  44  cancel_public_events                                          74999 non-null  object
#  45  workplace_closures                                            74999 non-null  object
#  46  school_closures                                               74999 non-null  int64
#  47  containment_index                                             74999 non-null  float64
#  48  public_information_campaigns                                  74999 non-null  object
#  49  facial_coverings                                              74999 non-null  object
#  50  vaccination_policy                                            74999 non-null  object
#  51  day of the week                                               74999 non-null  object
#  52  day of the week string                                        74999 non-null  object
#  53  day                                                           74999 non-null  int64
#  54  month                                                         74999 non-null  int64
#  55  year                                                          74999 non-null  int64
#  56  weekend                                                       74999 non-null  int64
#  57  death ratio                                                   74999 non-null  float64
#  58  continent                                                     74999 non-null  object
#  59  latitude                                                      74999 non-null  float64
#  60  longitude                                                     74999 non-null  float64
#  61  pop2022                                                       74999 non-null  float64
#  62  pop2021                                                       74999 non-null  float64
#  63  growthrate                                                    74999 non-null  float64
#  64  area                                                          74999 non-null  int64
#  65  density                                                       74999 non-null  float64
#  66  life expectancy(both sexes)                                   74999 non-null  float64
#  67  life expectancy(females)                                      74999 non-null  float64
#  68  life expectancy(males)                                        74999 non-null  float64
#  69  sub-region                                                    74999 non-null  object
#  70  income group                                                  74999 non-null  object
#  71  rural percentage(2021)                                        74999 non-null  float64
#  72  average temperature(1991-2020) c                              74999 non-null  float64
#  73  coldest month(1991-2020) c                                    74999 non-null  float64
#  74  hottest month(1991-2020) c                                    74999 non-null  float64
#  75  variation(1991-2020) c                                        74999 non-null  float64
#  76  no. of time zones                                             74999 non-null  int64
#  77  time zone                                                     74999 non-null  object
#  78  poverty percentage                                            74999 non-null  float64
#  79  legatumrank2020                                               74999 non-null  int64
#  80  legatumrank2019                                               74999 non-null  int64
# dtypes: datetime64[ns](1), float64(36), int64(21), object(23)
# memory usage: 46.9+ MB

# %%
print('Number of rows =', len(merged_df))
print('Number of columns =', len(merged_df.columns))
print('Number of countries =', len(merged_df['country'].unique()))
print('Number of rows for each country =',len(merged_df)/len(merged_df['country'].unique()))
print('With',merged_df.isna().sum().sum(),'Nulls')
print('Number of missing dates in the range between the min and max Dates =',
      len(pd.date_range(start=min(merged_df['date']), end=max(merged_df['date'])).difference(merged_df.date)), '(No gaps in the date column)')
# Out:
# Number of rows = 74999
# Number of columns = 81
# Number of countries = 82
# Number of rows for each country = 914.6219512195122
# With 0 Nulls
# Number of missing dates in the range between the min and max Dates = 0 (No gaps in the date column)
